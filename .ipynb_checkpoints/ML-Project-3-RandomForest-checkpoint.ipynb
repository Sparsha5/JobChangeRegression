# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
target=pd.read_csv('sample_submission.csv')

# %%
target.head()
# Out:
#    enrollee_id  target
# 0        32403     0.5
# 1         9858     0.5
# 2        31806     0.5
# 3        27385     0.5
# 4        27724     0.5

# %%
target.shape
# Out:
# (2129, 2)

# %%
target.dtypes
# Out:
# enrollee_id      int64
# target         float64
# dtype: object

# %%
df = pd.read_csv('aug_test.csv')
df.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# 2              NaN         <1          NaN      Pvt Ltd        never
# 3             STEM         11        10/49      Pvt Ltd            1
# 4             STEM        >20       10000+      Pvt Ltd           >4
#
#    training_hours
# 0              21
# 1              98
# 2              15
# 3              39
# 4              72

# %%
df_with_target = df.merge(target,how='inner')
df_with_target.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# 2              NaN         <1          NaN      Pvt Ltd        never
# 3             STEM         11        10/49      Pvt Ltd            1
# 4             STEM        >20       10000+      Pvt Ltd           >4
#
#    training_hours  target
# 0              21     0.5
# 1              98     0.5
# 2              15     0.5
# 3              39     0.5
# 4              72     0.5

# %%
X = df_with_target.drop(['target'],axis=1)
y = df_with_target[['target']]

# %%
X.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# 2              NaN         <1          NaN      Pvt Ltd        never
# 3             STEM         11        10/49      Pvt Ltd            1
# 4             STEM        >20       10000+      Pvt Ltd           >4
#
#    training_hours
# 0              21
# 1              98
# 2              15
# 3              39
# 4              72

# %%
y.mean()
# Out:
# target    0.5
# dtype: float64

# %%
#dropping id columns
X_wo_ids = X.drop(['enrollee_id'],axis=1)
X_wo_ids.head()
# Out:
#        city  city_development_index  gender      relevent_experience  \
# 0   city_41                   0.827    Male  Has relevent experience
# 1  city_103                   0.920  Female  Has relevent experience
# 2   city_21                   0.624    Male   No relevent experience
# 3   city_13                   0.827    Male  Has relevent experience
# 4  city_103                   0.920    Male  Has relevent experience
#
#   enrolled_university education_level major_discipline experience  \
# 0    Full time course        Graduate             STEM          9
# 1       no_enrollment        Graduate             STEM          5
# 2       no_enrollment     High School              NaN         <1
# 3       no_enrollment         Masters             STEM         11
# 4       no_enrollment        Graduate             STEM        >20
#
#   company_size company_type last_new_job  training_hours
# 0          <10          NaN            1              21
# 1          NaN      Pvt Ltd            1              98
# 2          NaN      Pvt Ltd        never              15
# 3        10/49      Pvt Ltd            1              39
# 4       10000+      Pvt Ltd           >4              72

# %%
#check null values  
X_wo_ids.isnull().mean()
# Out:
# city                      0.000000
# city_development_index    0.000000
# gender                    0.238610
# relevent_experience       0.000000
# enrolled_university       0.014561
# education_level           0.024425
# major_discipline          0.146548
# experience                0.002349
# company_size              0.292156
# company_type              0.297792
# last_new_job              0.018788
# training_hours            0.000000
# dtype: float64

# %% [markdown]
# ## Encode numerical feature

# %%
num = X_wo_ids.select_dtypes(include='number')
# adding region code as char as it is categorical data in num.
region_code = num[['Region_Code']]
num = num.drop(['Region_Code'],axis=1)

num.describe()
# Out:
#                  Age  Driving_License  Previously_Insured  Annual_Premium  \
# count  381109.000000    381109.000000       381109.000000   381109.000000
# mean       38.822584         0.997869            0.458210    30564.389581
# std        15.511611         0.046110            0.498251    17213.155057
# min        20.000000         0.000000            0.000000     2630.000000
# 25%        25.000000         1.000000            0.000000    24405.000000
# 50%        36.000000         1.000000            0.000000    31669.000000
# 75%        49.000000         1.000000            1.000000    39400.000000
# max        85.000000         1.000000            1.000000   540165.000000
#
#        Policy_Sales_Channel        Vintage
# count         381109.000000  381109.000000
# mean             112.034295     154.347397
# std               54.203995      83.671304
# min                1.000000      10.000000
# 25%               29.000000      82.000000
# 50%              133.000000     154.000000
# 75%              152.000000     227.000000
# max              163.000000     299.000000

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
num_1=pd.DataFrame(imputer.fit_transform(num),index=num.index,columns=num.columns)
num_1.head()
# Out:
#     Age  Driving_License  Previously_Insured  Annual_Premium  \
# 0  44.0              1.0                 0.0         40454.0
# 1  76.0              1.0                 0.0         33536.0
# 2  47.0              1.0                 0.0         38294.0
# 3  21.0              1.0                 1.0         28619.0
# 4  29.0              1.0                 1.0         27496.0
#
#    Policy_Sales_Channel  Vintage
# 0                  26.0    217.0
# 1                  26.0    183.0
# 2                  26.0     27.0
# 3                 152.0    203.0
# 4                 152.0     39.0

# %%
def outlier_capping(x):
    x = x.clip(upper=x.quantile(0.99))
    x = x.clip(lower=x.quantile(0.01))
    return x

# %%
num_1=num_1.apply(lambda x: outlier_capping(x))
num_1.describe(percentiles=[0.01,0.05,0.25,0.50,0.75,0.90,0.99])
# Out:
#                  Age  Driving_License  Previously_Insured  Annual_Premium  \
# count  381109.000000         381109.0       381109.000000   381109.000000
# mean       38.805688              1.0            0.458210    30338.717275
# std        15.468545              0.0            0.498251    15916.679308
# min        20.000000              1.0            0.000000     2630.000000
# 1%         20.000000              1.0            0.000000     2630.000000
# 5%         21.000000              1.0            0.000000     2630.000000
# 25%        25.000000              1.0            0.000000    24405.000000
# 50%        36.000000              1.0            0.000000    31669.000000
# 75%        49.000000              1.0            1.000000    39400.000000
# 90%        62.000000              1.0            1.000000    48431.000000
# 99%        77.000000              1.0            1.000000    72963.000000
# max        77.000000              1.0            1.000000    72963.000000
#
#        Policy_Sales_Channel        Vintage
# count         381109.000000  381109.000000
# mean             112.047724     154.347439
# std               54.111819      83.635716
# min                8.000000      12.000000
# 1%                 8.000000      12.000000
# 5%                26.000000      24.000000
# 25%               29.000000      82.000000
# 50%              133.000000     154.000000
# 75%              152.000000     227.000000
# 90%              156.000000     270.000000
# 99%              160.000000     297.000000
# max              160.000000     297.000000

# %% [markdown]
# ## Encode categorical feature

# %%
char = X_wo_ids.select_dtypes(include='object')
char.head()
# Out:
#    Gender Vehicle_Age Vehicle_Damage
# 0    Male   > 2 Years            Yes
# 1    Male    1-2 Year             No
# 2    Male   > 2 Years            Yes
# 3    Male    < 1 Year             No
# 4  Female    < 1 Year             No

# %%
char_encode = pd.get_dummies(char,drop_first=True)
char_encode.head()
# Out:
#    Gender_Male  Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years  \
# 0            1                     0                      1
# 1            1                     0                      0
# 2            1                     0                      1
# 3            1                     1                      0
# 4            0                     1                      0
#
#    Vehicle_Damage_Yes
# 0                   1
# 1                   0
# 2                   1
# 3                   0
# 4                   0

# %%
region_code['Region_Code'].value_counts()
# Out:
# 28.0    106415
# 8.0      33877
# 46.0     19749
# 41.0     18263
# 15.0     13308
# 30.0     12191
# 29.0     11065
# 50.0     10243
# 3.0       9251
# 11.0      9232
# 36.0      8797
# 33.0      7654
# 47.0      7436
# 35.0      6942
# 6.0       6280
# 45.0      5605
# 37.0      5501
# 18.0      5153
# 48.0      4681
# 14.0      4678
# 39.0      4644
# 10.0      4374
# 21.0      4266
# 2.0       4038
# 13.0      4036
# 7.0       3279
# 12.0      3198
# 9.0       3101
# 27.0      2823
# 32.0      2787
# 43.0      2639
# 17.0      2617
# 26.0      2587
# 25.0      2503
# 24.0      2415
# 38.0      2026
# 0.0       2021
# 16.0      2007
# 31.0      1960
# 23.0      1960
# 20.0      1935
# 49.0      1832
# 4.0       1801
# 34.0      1664
# 19.0      1535
# 22.0      1309
# 40.0      1295
# 5.0       1279
# 1.0       1008
# 44.0       808
# 42.0       591
# 52.0       267
# 51.0       183
# Name: Region_Code, dtype: int64

# %%
char_all = pd.concat([region_code,char_encode],axis=1,join='inner')
char_all.head()
# Out:
#    Region_Code  Gender_Male  Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years  \
# 0         28.0            1                     0                      1
# 1          3.0            1                     0                      0
# 2         28.0            1                     0                      1
# 3         11.0            1                     1                      0
# 4         41.0            0                     1                      0
#
#    Vehicle_Damage_Yes
# 0                   1
# 1                   0
# 2                   1
# 3                   0
# 4                   0

# %% [markdown]
# ## Feature Discretization

# %%
from sklearn.preprocessing import KBinsDiscretizer
Bins=KBinsDiscretizer(n_bins=5,encode='ordinal',strategy='quantile')
X_binned=pd.DataFrame(Bins.fit_transform(num_1),index=num_1.index, columns=num_1.columns).add_suffix('_Bin')
X_binned.describe()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:167: UserWarning: Feature 1 is constant and will be replaced with 0.
#   warnings.warn("Feature %d is constant and will be "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:200: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 2 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:200: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 4 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
#              Age_Bin  Driving_License_Bin  Previously_Insured_Bin  \
# count  381109.000000             381109.0                381109.0
# mean        2.047506                  0.0                     0.0
# std         1.392045                  0.0                     0.0
# min         0.000000                  0.0                     0.0
# 25%         1.000000                  0.0                     0.0
# 50%         2.000000                  0.0                     0.0
# 75%         3.000000                  0.0                     0.0
# max         4.000000                  0.0                     0.0
#
#        Annual_Premium_Bin  Policy_Sales_Channel_Bin    Vintage_Bin
# count       381109.000000             381109.000000  381109.000000
# mean             2.000029                  2.143549       2.008942
# std              1.414227                  0.942784       1.417849
# min              0.000000                  0.000000       0.000000
# 25%              1.000000                  1.000000       1.000000
# 50%              2.000000                  2.000000       2.000000
# 75%              3.000000                  3.000000       3.000000
# max              4.000000                  3.000000       4.000000

# %%
X_binned=pd.concat([X_binned,y],axis=1,join="inner")
X_binned
# Out:
#         Age_Bin  Driving_License_Bin  Previously_Insured_Bin  \
# 0           3.0                  0.0                     0.0
# 1           4.0                  0.0                     0.0
# 2           3.0                  0.0                     0.0
# 3           0.0                  0.0                     0.0
# 4           2.0                  0.0                     0.0
# ...         ...                  ...                     ...
# 381104      4.0                  0.0                     0.0
# 381105      2.0                  0.0                     0.0
# 381106      0.0                  0.0                     0.0
# 381107      4.0                  0.0                     0.0
# 381108      3.0                  0.0                     0.0
#
#         Annual_Premium_Bin  Policy_Sales_Channel_Bin  Vintage_Bin  Response
# 0                      3.0                       1.0          3.0         1
# 1                      2.0                       1.0          3.0         0
# 2                      3.0                       1.0          0.0         1
# 3                      1.0                       3.0          3.0         0
# 4                      1.0                       3.0          0.0         0
# ...                    ...                       ...          ...       ...
# 381104                 2.0                       1.0          1.0         0
# 381105                 3.0                       3.0          2.0         0
# 381106                 3.0                       3.0          2.0         0
# 381107                 4.0                       2.0          1.0         0
# 381108                 4.0                       1.0          3.0         0
#
# [381109 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
from numpy import mean
for col in (X_binned.columns):
    plt.figure()
    ax=sns.lineplot(x=col,y='Response',data=X_binned,estimator=mean)
    plt.show()

# %%
num_2 = num_1.drop(['Vintage','Driving_License','Previously_Insured'],axis=1)
num_2.head()
# Out:
#     Age  Annual_Premium  Policy_Sales_Channel
# 0  44.0         40454.0                  26.0
# 1  76.0         33536.0                  26.0
# 2  47.0         38294.0                  26.0
# 3  21.0         28619.0                 152.0
# 4  29.0         27496.0                 152.0

# %%
char_feature_check=pd.concat([char_all,y],axis=1,join="inner")

# %%
import matplotlib.pyplot as plt
from numpy import mean
for col in (char_feature_check.columns):
    plt.figure()
    #ax=sns.relplot(x=col,y='Response',data=char_feature_check,kind='line',estimator=mean)
    ax=sns.lineplot(x=col,y='Response',data=char_feature_check,estimator=mean)
    plt.show()

# %% [markdown]
# ## Final DataSet For ModelBuilding

# %%
X_all = pd.concat([num_2,char_all],axis=1,join='inner')
X_all.head()
# Out:
#     Age  Annual_Premium  Policy_Sales_Channel  Region_Code  Gender_Male  \
# 0  44.0         40454.0                  26.0         28.0            1
# 1  76.0         33536.0                  26.0          3.0            1
# 2  47.0         38294.0                  26.0         28.0            1
# 3  21.0         28619.0                 152.0         11.0            1
# 4  29.0         27496.0                 152.0         41.0            0
#
#    Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years  Vehicle_Damage_Yes
# 0                     0                      1                   1
# 1                     0                      0                   0
# 2                     0                      1                   1
# 3                     1                      0                   0
# 4                     1                      0                   0

# %% [markdown]
# ## Feature Scaling

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X_std = pd.DataFrame(sc.fit_transform(X_all),index=X_all.index, columns=X_all.columns).add_suffix('_std')

# %%
#X_std.shape

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =  train_test_split(X_all,y, test_size=0.3,random_state=42)

# %%
y_train.mean()
# Out:
# Response    0.122095
# dtype: float64

# %%
y_test.mean()
# Out:
# Response    0.123656
# dtype: float64

# %%
X_test.shape
# Out:
# (114333, 8)

# %%
X_train.shape
# Out:
# (266776, 8)

# %% [markdown]
# ## RandomForest Implementation

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# <ipython-input-105-4fb9db1ddab0>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train,y_train)
# RandomForestClassifier()

# %%
y_pred=rf.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision",metrics.precision_score(y_test,y_pred))
print("Recall",metrics.recall_score(y_test,y_pred))
print("f1_score",metrics.f1_score(y_test,y_pred))
# Out:
# Accuracy: 0.8502532077352996
# Precision 0.3295623357330591
# Recall 0.2039892488329325
# f1_score 0.25199877670496745

# %%
metrics.plot_confusion_matrix(rf,X_test,y_test)

# %%
metrics.roc_auc_score(y_test,y_pred)
# Out:
# 0.5727167163372208

# %% [markdown]
# ## Visualizing model

# %%
y_pred_prob = rf.predict_proba(X_all)[:, 1]
df['y_pred_P']=pd.DataFrame(y_pred_prob)
df['P_Rank']=pd.qcut(df['y_pred_P'].rank(method='first').values,10,duplicates='drop').codes+1
rank_df=df.groupby('P_Rank')['Response'].agg(['count','mean'])
rank_df=pd.DataFrame(rank_df)
sorted_rank_df=rank_df.sort_values(by='P_Rank',ascending=False)
sorted_rank_df['N_events']=rank_df['count']*rank_df['mean']
sorted_rank_df['cum_events']=sorted_rank_df['N_events'].cumsum()
sorted_rank_df['event_cap']=sorted_rank_df['N_events']/max(sorted_rank_df['N_events'].cumsum())
sorted_rank_df['cum_event_cap']=sorted_rank_df['event_cap'].cumsum()
sorted_rank_df['random_cap']=sorted_rank_df['count']/max(sorted_rank_df['count'].cumsum())
sorted_rank_df['cum_random_cap']=sorted_rank_df['random_cap'].cumsum()
sorted_rank_df
sorted_reindexed=sorted_rank_df.reset_index()
sorted_reindexed['decile']=sorted_reindexed.index+1
sorted_reindexed['lift_over_random']=sorted_reindexed['cum_event_cap']/sorted_reindexed['cum_random_cap']
sorted_reindexed
# Out:
#    P_Rank  count      mean  N_events  cum_events  event_cap  cum_event_cap  \
# 0      10  38111  0.846737   32270.0     32270.0   0.690858       0.690858
# 1       9  38111  0.214085    8159.0     40429.0   0.174674       0.865532
# 2       8  38111  0.078770    3002.0     43431.0   0.064269       0.929801
# 3       7  38111  0.043741    1667.0     45098.0   0.035688       0.965489
# 4       6  38110  0.026030     992.0     46090.0   0.021237       0.986727
# 5       5  38111  0.003621     138.0     46228.0   0.002954       0.989681
# 6       4  38111  0.003018     115.0     46343.0   0.002462       0.992143
# 7       3  38111  0.003359     128.0     46471.0   0.002740       0.994883
# 8       2  38111  0.003621     138.0     46609.0   0.002954       0.997838
# 9       1  38111  0.002650     101.0     46710.0   0.002162       1.000000
#
#    random_cap  cum_random_cap  decile  lift_over_random
# 0    0.100000        0.100000       1          6.908567
# 1    0.100000        0.200001       2          4.327649
# 2    0.100000        0.300001       3          3.099328
# 3    0.100000        0.400001       4          2.413717
# 4    0.099998        0.499999       5          1.973458
# 5    0.100000        0.599999       6          1.649471
# 6    0.100000        0.699999       7          1.417349
# 7    0.100000        0.799999       8          1.243605
# 8    0.100000        0.900000       9          1.108709
# 9    0.100000        1.000000      10          1.000000

# %%
ax = sns.lineplot( x="decile", y="cum_event_cap", data=sorted_reindexed)
ax = sns.lineplot( x="decile", y="cum_random_cap", data=sorted_reindexed)

# %%
ax = sns.lineplot( x="decile", y="lift_over_random", data=sorted_reindexed)
ax = sns.lineplot( x="decile", y="random_cap", data=sorted_reindexed)

# %%
df.groupby('P_Rank')['y_pred_P'].agg(['min','max'])
# Out:
#          min   max
# P_Rank
# 1       0.00  0.00
# 2       0.00  0.00
# 3       0.00  0.00
# 4       0.00  0.00
# 5       0.00  0.00
# 6       0.00  0.03
# 7       0.03  0.08
# 8       0.08  0.19
# 9       0.19  0.52
# 10      0.52  1.00

# %%
df.loc[df['P_Rank']>=7,:]
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 2            3    Male   47                1         28.0                   0
# 7            8  Female   56                1         28.0                   0
# 10          11  Female   47                1         35.0                   0
# 13          14    Male   76                1         28.0                   0
# ...        ...     ...  ...              ...          ...                 ...
# 381100  381101  Female   29                1         28.0                   0
# 381101  381102  Female   70                1         28.0                   0
# 381103  381104    Male   47                1         50.0                   0
# 381104  381105    Male   74                1         26.0                   1
# 381107  381108  Female   68                1         14.0                   0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0        > 2 Years            Yes         40454.0                  26.0
# 2        > 2 Years            Yes         38294.0                  26.0
# 7         1-2 Year            Yes         32031.0                  26.0
# 10        1-2 Year            Yes         47576.0                 124.0
# 13        1-2 Year            Yes         36770.0                  13.0
# ...            ...            ...             ...                   ...
# 381100    < 1 Year            Yes         49007.0                 124.0
# 381101   > 2 Years            Yes         50904.0                 122.0
# 381103    1-2 Year            Yes         39831.0                  26.0
# 381104    1-2 Year             No         30170.0                  26.0
# 381107   > 2 Years            Yes         44617.0                 124.0
#
#         Vintage  Response  y_pred_P  P_Rank
# 0           217         1      0.31       9
# 2            27         1      0.56      10
# 7            72         1      0.05       7
# 10           46         1      0.69      10
# 13           15         0      0.06       7
# ...         ...       ...       ...     ...
# 381100      137         0      0.07       7
# 381101      215         0      0.12       8
# 381103      235         0      0.22       9
# 381104       88         0      0.06       7
# 381107       74         0      0.07       7
#
# [152444 rows x 14 columns]

# %%
X_all.corr()
# Out:
#                             Age  Annual_Premium  Policy_Sales_Channel  \
# Age                    1.000000        0.068997             -0.579095
# Annual_Premium         0.068997        1.000000             -0.119381
# Policy_Sales_Channel  -0.579095       -0.119381              1.000000
# Region_Code            0.042541       -0.011129             -0.042616
# Gender_Male            0.145987        0.003974             -0.111419
# Vehicle_Age_< 1 Year  -0.789018       -0.021482              0.572769
# Vehicle_Age_> 2 Years  0.220929        0.064874             -0.146422
# Vehicle_Damage_Yes     0.268132        0.008588             -0.225232
#
#                        Region_Code  Gender_Male  Vehicle_Age_< 1 Year  \
# Age                       0.042541     0.145987             -0.789018
# Annual_Premium           -0.011129     0.003974             -0.021482
# Policy_Sales_Channel     -0.042616    -0.111419              0.572769
# Region_Code               1.000000     0.000604             -0.044250
# Gender_Male               0.000604     1.000000             -0.166280
# Vehicle_Age_< 1 Year     -0.044250    -0.166280              1.000000
# Vehicle_Age_> 2 Years     0.014555     0.043155             -0.182750
# Vehicle_Damage_Yes        0.028235     0.091606             -0.370778
#
#                        Vehicle_Age_> 2 Years  Vehicle_Damage_Yes
# Age                                 0.220929            0.268132
# Annual_Premium                      0.064874            0.008588
# Policy_Sales_Channel               -0.146422           -0.225232
# Region_Code                         0.014555            0.028235
# Gender_Male                         0.043155            0.091606
# Vehicle_Age_< 1 Year               -0.182750           -0.370778
# Vehicle_Age_> 2 Years               1.000000            0.206961
# Vehicle_Damage_Yes                  0.206961            1.000000
